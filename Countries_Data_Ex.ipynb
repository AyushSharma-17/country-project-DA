# %% [markdown]
# <h1><b><center>DATA CAPSTONE PROJECT <center></b></h1>

# %% [markdown]
# <h3>A data extraction project related to countries data and data is taken from the kaggle.
# Data is related to countries and their informations.</h3>
